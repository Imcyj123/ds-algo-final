# %% [markdown]
# # task 1

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import time
import math
start = time.time()

class Component:
    def __init__(self, type, dimensions, quantity):
        self.type = type
        self.dimensions = dimensions
        self.quantity = quantity
        self.remaining_quantity = quantity

def pack_components(material_width, material_height, components, max_iterations=1000):
    packed_items = []
    used_area = 0
    components.sort(key=lambda x: x.dimensions[0] * x.dimensions[1], reverse=True)
    material_grid = [[0 for _ in range(material_width)] for _ in range(material_height)]
    for _ in range(max_iterations):
        all_placed = True
        for idx in range(len(components)):
            placed_quantity = 0
            i = 0
            for i in range(material_height):
                j = 0
                for j in range(material_width):
                    if components[idx].remaining_quantity > 0 and try_place_component(material_grid, i, j, components[idx]):
                        packed_items.append((i, j, components[idx]))
                        components[idx].remaining_quantity -= 1
                        placed_quantity += 1
                        cur[idx]+=1
                        if components[idx].type == "Rectangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1]
                        elif components[idx].type == "Circle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.pi / 4
                        elif components[idx].type == "Triangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.sqrt(3) / 4
                        all_placed = False
        remaining_area = material_width * material_height - used_area
        if remaining_area <= 0 or all_placed:
            break
    return packed_items, remaining_area


def try_place_component(material_grid, row, col, component):
    height, width = len(material_grid), len(material_grid[0])
    if row + component.dimensions[0] > height or col + component.dimensions[1] > width:
        return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            if material_grid[row + i][col + j] != 0:
                return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            material_grid[row + i][col + j] = component.type
    return True
def plot_packing(material_width, material_height, packed_items):
    fig, ax = plt.subplots()
    ax.set_xlim([0, material_width])
    ax.set_ylim([0, material_height])
    for item in packed_items:
        component = item[2]
        if component.type == "Rectangle":
            rect = patches.Rectangle((item[1], item[0]), component.dimensions[1], component.dimensions[0], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(rect)
        elif component.type == "Circle":
            circle = patches.Circle((item[1] + component.dimensions[1] / 2, item[0] + component.dimensions[0] / 2), component.dimensions[1] / 2, linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(circle)
        elif component.type == "Triangle":
            triangle = patches.Polygon([
                (item[1], item[0] + component.dimensions[0]),
                (item[1] + component.dimensions[1] / 2, item[0]),
                (item[1] + component.dimensions[1], item[0] + component.dimensions[0])
            ], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(triangle)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title(f'Packing Result for Components')
    plt.show()
components = [
  Component("Rectangle", (20, 50), 10),
  Component("Rectangle", (20, 15), 20),
  Component("Rectangle", (15, 15), 10),
  Component("Triangle", (10, 10), 20),
  Component("Triangle", (15, 15), 15),
  Component("Circle", (10, 10), 15),
  Component("Circle", (20, 20), 40),
]
cnt = [0 for _ in components]
remaining_area_array = []
used = 0
while sum([i.remaining_quantity for i in components]) != 0:
    cur = [0 for _ in components]
    each_time = time.time()
    used += 1
    material_width = 200
    material_height = 100
    area = material_width * material_height
    packed_items, remaining_area = pack_components(material_width, material_height, components)
    plot_packing(material_width, material_height, packed_items)
    print(f"Remaining Area%: {remaining_area / area}")
    remaining_area_array.append(float(remaining_area / area))
    print(f" each time : {time.time() - each_time}")
    cnt = [x + y for x, y in zip(cnt, cur)]
    for i, component in enumerate(components):
        print(f"{i + 1}. {component.type},{component.dimensions}, {component.quantity}, remaining: {component.remaining_quantity}, total_count: {cnt[i]}, count: {cur[i]}")
print(f' total use time {time.time()-start}')
print(f' use leather {used} pieces')
print(f' remaining_area {remaining_area_array}')
# Out:
# Remaining Area%: 0.10730091830127549
#  each time : 0.4230458736419678
# 1. Rectangle,(20, 50), 10, remaining: 0, total_count: 10, count: 10
# 2. Circle,(20, 20), 40, remaining: 15, total_count: 25, count: 25
# 3. Rectangle,(20, 15), 20, remaining: 20, total_count: 0, count: 0
# 4. Rectangle,(15, 15), 10, remaining: 10, total_count: 0, count: 0
# 5. Triangle,(15, 15), 15, remaining: 15, total_count: 0, count: 0
# 6. Triangle,(10, 10), 20, remaining: 20, total_count: 0, count: 0
# 7. Circle,(10, 10), 15, remaining: 15, total_count: 0, count: 0
# Remaining Area%: 0.235508387347231
#  each time : 0.2909972667694092
# 1. Rectangle,(20, 50), 10, remaining: 0, total_count: 10, count: 0
# 2. Circle,(20, 20), 40, remaining: 0, total_count: 40, count: 15
# 3. Rectangle,(20, 15), 20, remaining: 0, total_count: 20, count: 20
# 4. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 10
# 5. Triangle,(15, 15), 15, remaining: 0, total_count: 15, count: 15
# 6. Triangle,(10, 10), 20, remaining: 0, total_count: 20, count: 20
# 7. Circle,(10, 10), 15, remaining: 15, total_count: 0, count: 0
# Remaining Area%: 0.9410951377451915
#  each time : 0.15900397300720215
# 1. Rectangle,(20, 50), 10, remaining: 0, total_count: 10, count: 0
# 2. Circle,(20, 20), 40, remaining: 0, total_count: 40, count: 0
# 3. Rectangle,(20, 15), 20, remaining: 0, total_count: 20, count: 0
# 4. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# 5. Triangle,(15, 15), 15, remaining: 0, total_count: 15, count: 0
# 6. Triangle,(10, 10), 20, remaining: 0, total_count: 20, count: 0
# 7. Circle,(10, 10), 15, remaining: 0, total_count: 15, count: 15
#  total use time 0.8750307559967041
#  use leather 3 pieces
#  remaining_area [0.10730091830127549, 0.235508387347231, 0.9410951377451915]

# %% [markdown]
# # task 2

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import time
import math
start = time.time()

class Component:
    def __init__(self, type, dimensions, quantity):
        self.type = type
        self.dimensions = dimensions
        self.quantity = quantity
        self.remaining_quantity = quantity

def pack_components(material_width, material_height, components, max_iterations=1000):
    packed_items = []
    used_area = 0
    components.sort(key=lambda x: x.dimensions[0] * x.dimensions[1], reverse=True)
    material_grid = [[0 for _ in range(material_width)] for _ in range(material_height)]
    for _ in range(max_iterations):
        all_placed = True
        for idx in range(len(components)):
            placed_quantity = 0
            i = 0
            for i in range(material_height):
                j = 0
                for j in range(material_width):
                    if components[idx].remaining_quantity > 0 and try_place_component(material_grid, i, j, components[idx]):
                        packed_items.append((i, j, components[idx]))
                        components[idx].remaining_quantity -= 1
                        placed_quantity += 1
                        cur[idx]+=1
                        if components[idx].type == "Rectangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1]
                        elif components[idx].type == "Circle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.pi / 4
                        elif components[idx].type == "Triangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.sqrt(3) / 4
                        all_placed = False
        remaining_area = material_width * material_height - used_area
        if remaining_area <= 0 or all_placed:
            break
    return packed_items, remaining_area


def try_place_component(material_grid, row, col, component):
    height, width = len(material_grid), len(material_grid[0])
    if row + component.dimensions[0] > height or col + component.dimensions[1] > width:
        return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            if material_grid[row + i][col + j] != 0:
                return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            material_grid[row + i][col + j] = component.type
    return True
def plot_packing(material_width, material_height, packed_items):
    fig, ax = plt.subplots()
    ax.set_xlim([0, material_width])
    ax.set_ylim([0, material_height])
    for item in packed_items:
        component = item[2]
        if component.type == "Rectangle":
            rect = patches.Rectangle((item[1], item[0]), component.dimensions[1], component.dimensions[0], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(rect)
        elif component.type == "Circle":
            circle = patches.Circle((item[1] + component.dimensions[1] / 2, item[0] + component.dimensions[0] / 2), component.dimensions[1] / 2, linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(circle)
        elif component.type == "Triangle":
            triangle = patches.Polygon([
                (item[1], item[0] + component.dimensions[0]),
                (item[1] + component.dimensions[1] / 2, item[0]),
                (item[1] + component.dimensions[1], item[0] + component.dimensions[0])
            ], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(triangle)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title(f'Packing Result for Components')
    plt.show()
components = [
  Component("Rectangle", (10, 50), 20),
  Component("Rectangle", (10, 25), 20),
  Component("Rectangle", (15, 15), 10),
  Component("Triangle", (50, 50), 20),
  Component("Triangle", (65, 65), 15),
  Component("Circle", (50, 50), 100),
  Component("Circle", (60, 60), 40),
]
cnt = [0 for _ in components]
remaining_area_array = []
used = 0
while sum([i.remaining_quantity for i in components]) != 0:
    cur = [0 for _ in components]
    each_time = time.time()
    used += 1
    material_width = 200
    material_height = 200
    area = material_width * material_height
    packed_items, remaining_area = pack_components(material_width, material_height, components)
    plot_packing(material_width, material_height, packed_items)
    print(f"Remaining Area%: {remaining_area / area}")
    remaining_area_array.append(float(remaining_area / area))
    print(f" each time : {time.time() - each_time}")
    cnt = [x + y for x, y in zip(cnt, cur)]
    for i, component in enumerate(components):
        print(f"{i + 1}. {component.type},{component.dimensions}, {component.quantity}, remaining: {component.remaining_quantity}, total_count: {cnt[i]}, count: {cur[i]}")
print(f' total use time {time.time()-start}')
print(f' use leather {used} pieces')
print(f' remaining_area {remaining_area_array}')
# Out:
# Remaining Area%: 0.5883673002637092
#  each time : 0.5329763889312744
# 1. Triangle,(65, 65), 15, remaining: 6, total_count: 9, count: 9
# 2. Circle,(60, 60), 40, remaining: 40, total_count: 0, count: 0
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 20, total_count: 0, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 20, total_count: 0, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.4410206960584951
#  each time : 0.5320296287536621
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 6
# 2. Circle,(60, 60), 40, remaining: 37, total_count: 3, count: 3
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 16, total_count: 4, count: 4
# 6. Rectangle,(10, 25), 20, remaining: 20, total_count: 0, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 6, total_count: 4, count: 4
# Remaining Area%: 0.23007748764806701
#  each time : 0.446012020111084
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 28, total_count: 12, count: 9
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 8, total_count: 12, count: 8
# 6. Rectangle,(10, 25), 20, remaining: 20, total_count: 0, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 6
# Remaining Area%: 0.263827487648067
#  each time : 0.38004446029663086
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 19, total_count: 21, count: 9
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 8
# 6. Rectangle,(10, 25), 20, remaining: 20, total_count: 0, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.263827487648067
#  each time : 0.4143824577331543
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 10, total_count: 30, count: 9
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 4, total_count: 16, count: 16
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.338827487648067
#  each time : 0.33901333808898926
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 1, total_count: 39, count: 9
# 3. Triangle,(50, 50), 20, remaining: 20, total_count: 0, count: 0
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 4
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.6045546388750652
#  each time : 0.24400663375854492
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 1
# 3. Triangle,(50, 50), 20, remaining: 8, total_count: 12, count: 12
# 4. Circle,(50, 50), 100, remaining: 100, total_count: 0, count: 0
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.39079456735516604
#  each time : 0.22059249877929688
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 8
# 4. Circle,(50, 50), 100, remaining: 92, total_count: 8, count: 8
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.21460183660255144
#  each time : 0.24801135063171387
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 76, total_count: 24, count: 16
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.21460183660255144
#  each time : 0.22603464126586914
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 60, total_count: 40, count: 16
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.21460183660255144
#  each time : 0.22898507118225098
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 44, total_count: 56, count: 16
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.21460183660255144
#  each time : 0.2660179138183594
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 28, total_count: 72, count: 16
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.21460183660255144
#  each time : 0.2340090274810791
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 12, total_count: 88, count: 16
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
# Remaining Area%: 0.41095137745191357
#  each time : 0.20200490951538086
# 1. Triangle,(65, 65), 15, remaining: 0, total_count: 15, count: 0
# 2. Circle,(60, 60), 40, remaining: 0, total_count: 40, count: 0
# 3. Triangle,(50, 50), 20, remaining: 0, total_count: 20, count: 0
# 4. Circle,(50, 50), 100, remaining: 0, total_count: 100, count: 12
# 5. Rectangle,(10, 50), 20, remaining: 0, total_count: 20, count: 0
# 6. Rectangle,(10, 25), 20, remaining: 0, total_count: 20, count: 0
# 7. Rectangle,(15, 15), 10, remaining: 0, total_count: 10, count: 0
#  total use time 4.517131090164185
#  use leather 14 pieces
#  remaining_area [0.5883673002637092, 0.4410206960584951, 0.23007748764806701, 0.263827487648067, 0.263827487648067, 0.338827487648067, 0.6045546388750652, 0.39079456735516604, 0.21460183660255144, 0.21460183660255144, 0.21460183660255144, 0.21460183660255144, 0.21460183660255144, 0.41095137745191357]

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import time
import math
start = time.time()

class Component:
    def __init__(self, type, dimensions, quantity):
        self.type = type
        self.dimensions = dimensions
        self.quantity = quantity
        self.remaining_quantity = quantity

def pack_components(material_width, material_height, components, max_iterations=1000):
    packed_items = []
    used_area = 0
    components.sort(key=lambda x: x.dimensions[0] * x.dimensions[1], reverse=True)
    material_grid = [[0 for _ in range(material_width)] for _ in range(material_height)]
    for _ in range(max_iterations):
        all_placed = True
        for idx in range(len(components)):
            placed_quantity = 0
            i = 0
            for i in range(material_height):
                j = 0
                for j in range(material_width):
                    if components[idx].remaining_quantity > 0 and try_place_component(material_grid, i, j, components[idx]):
                        packed_items.append((i, j, components[idx]))
                        components[idx].remaining_quantity -= 1
                        placed_quantity += 1
                        cur[idx]+=1
                        if components[idx].type == "Rectangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1]
                        elif components[idx].type == "Circle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.pi / 4
                        elif components[idx].type == "Triangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.sqrt(3) / 4
                        all_placed = False
        remaining_area = material_width * material_height - used_area
        if remaining_area <= 0 or all_placed:
            break
    return packed_items, remaining_area


def try_place_component(material_grid, row, col, component):
    height, width = len(material_grid), len(material_grid[0])
    if row + component.dimensions[0] > height or col + component.dimensions[1] > width:
        return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            if material_grid[row + i][col + j] != 0:
                return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            material_grid[row + i][col + j] = component.type
    return True
def plot_packing(material_width, material_height, packed_items):
    fig, ax = plt.subplots()
    ax.set_xlim([0, material_width])
    ax.set_ylim([0, material_height])
    for item in packed_items:
        component = item[2]
        if component.type == "Rectangle":
            rect = patches.Rectangle((item[1], item[0]), component.dimensions[1], component.dimensions[0], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(rect)
        elif component.type == "Circle":
            circle = patches.Circle((item[1] + component.dimensions[1] / 2, item[0] + component.dimensions[0] / 2), component.dimensions[1] / 2, linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(circle)
        elif component.type == "Triangle":
            triangle = patches.Polygon([
                (item[1], item[0] + component.dimensions[0]),
                (item[1] + component.dimensions[1] / 2, item[0]),
                (item[1] + component.dimensions[1], item[0] + component.dimensions[0])
            ], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(triangle)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title(f'Packing Result for Components')
    plt.show()
components = [
  Component("Rectangle", (30, 8), 100),
  Component("Rectangle", (25, 5), 20),
  Component("Rectangle", (5, 5), 10),
  Component("Triangle", (10, 10), 200),
  Component("Triangle", (8, 8), 200),
  Component("Circle", (20, 20), 200),
  Component("Circle", (16, 16), 600),
]
cnt = [0 for _ in components]
remaining_area_array = []
used = 0
while sum([i.remaining_quantity for i in components]) != 0:
    cur = [0 for _ in components]
    each_time = time.time()
    used += 1
    material_width = 100
    material_height = 300
    area = material_width * material_height
    packed_items, remaining_area = pack_components(material_width, material_height, components)
    plot_packing(material_width, material_height, packed_items)
    print(f"Remaining Area%: {remaining_area / area}")
    remaining_area_array.append(float(remaining_area / area))
    print(f" each time : {time.time() - each_time}")
    cnt = [x + y for x, y in zip(cnt, cur)]
    for i, component in enumerate(components):
        print(f"{i + 1}. {component.type},{component.dimensions}, {component.quantity}, remaining: {component.remaining_quantity}, total_count: {cnt[i]}, count: {cur[i]}")
print(f' total use time {time.time()-start}')
print(f' use leather {used} pieces')
print(f' remaining_area {remaining_area_array}')
# Out:
# Remaining Area%: 0.21460183660255122
#  each time : 0.6870255470275879
# 1. Circle,(20, 20), 200, remaining: 125, total_count: 75, count: 75
# 2. Circle,(16, 16), 600, remaining: 600, total_count: 0, count: 0
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 200, total_count: 0, count: 0
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.21460183660255122
#  each time : 0.7780296802520752
# 1. Circle,(20, 20), 200, remaining: 50, total_count: 150, count: 75
# 2. Circle,(16, 16), 600, remaining: 600, total_count: 0, count: 0
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 200, total_count: 0, count: 0
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2351269086060055
#  each time : 0.7278406620025635
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 50
# 2. Circle,(16, 16), 600, remaining: 564, total_count: 36, count: 36
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 200, total_count: 0, count: 0
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2617432958831722
#  each time : 0.7570240497589111
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 456, total_count: 144, count: 108
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 190, total_count: 10, count: 10
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2617432958831722
#  each time : 0.7930295467376709
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 348, total_count: 252, count: 108
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 180, total_count: 20, count: 10
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2617432958831722
#  each time : 0.7600510120391846
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 240, total_count: 360, count: 108
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 170, total_count: 30, count: 10
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2617432958831722
#  each time : 0.7540538311004639
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 132, total_count: 468, count: 108
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 160, total_count: 40, count: 10
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.2617432958831722
#  each time : 0.7599997520446777
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 24, total_count: 576, count: 108
# 3. Rectangle,(30, 8), 100, remaining: 100, total_count: 0, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(10, 10), 200, remaining: 150, total_count: 50, count: 10
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.0838171228028692
#  each time : 0.5710484981536865
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 0, total_count: 600, count: 24
# 3. Rectangle,(30, 8), 100, remaining: 16, total_count: 84, count: 84
# 4. Rectangle,(25, 5), 20, remaining: 0, total_count: 20, count: 20
# 5. Triangle,(10, 10), 200, remaining: 150, total_count: 50, count: 0
# 6. Triangle,(8, 8), 200, remaining: 200, total_count: 0, count: 0
# 7. Rectangle,(5, 5), 10, remaining: 10, total_count: 0, count: 0
# Remaining Area%: 0.5021299281001252
#  each time : 0.4983794689178467
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 0, total_count: 600, count: 0
# 3. Rectangle,(30, 8), 100, remaining: 0, total_count: 100, count: 16
# 4. Rectangle,(25, 5), 20, remaining: 0, total_count: 20, count: 0
# 5. Triangle,(10, 10), 200, remaining: 0, total_count: 200, count: 150
# 6. Triangle,(8, 8), 200, remaining: 43, total_count: 157, count: 157
# 7. Rectangle,(5, 5), 10, remaining: 0, total_count: 10, count: 10
# Remaining Area%: 0.9602783014797538
#  each time : 0.14527201652526855
# 1. Circle,(20, 20), 200, remaining: 0, total_count: 200, count: 0
# 2. Circle,(16, 16), 600, remaining: 0, total_count: 600, count: 0
# 3. Rectangle,(30, 8), 100, remaining: 0, total_count: 100, count: 0
# 4. Rectangle,(25, 5), 20, remaining: 0, total_count: 20, count: 0
# 5. Triangle,(10, 10), 200, remaining: 0, total_count: 200, count: 0
# 6. Triangle,(8, 8), 200, remaining: 0, total_count: 200, count: 43
# 7. Rectangle,(5, 5), 10, remaining: 0, total_count: 10, count: 0
#  total use time 7.2361414432525635
#  use leather 11 pieces
#  remaining_area [0.21460183660255122, 0.21460183660255122, 0.2351269086060055, 0.2617432958831722, 0.2617432958831722, 0.2617432958831722, 0.2617432958831722, 0.2617432958831722, 0.0838171228028692, 0.5021299281001252, 0.9602783014797538]

# %% [markdown]
# ## Random task

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import time
import math
start = time.time()

class Component:
    def __init__(self, type, dimensions, quantity):
        self.type = type
        self.dimensions = dimensions
        self.quantity = quantity
        self.remaining_quantity = quantity

def pack_components(material_width, material_height, components, max_iterations=1000):
    packed_items = []
    used_area = 0
    components.sort(key=lambda x: x.dimensions[0] * x.dimensions[1], reverse=True)
    material_grid = [[0 for _ in range(material_width)] for _ in range(material_height)]
    for _ in range(max_iterations):
        all_placed = True
        for idx in range(len(components)):
            placed_quantity = 0
            i = 0
            for i in range(material_height):
                j = 0
                for j in range(material_width):
                    if components[idx].remaining_quantity > 0 and try_place_component(material_grid, i, j, components[idx]):
                        packed_items.append((i, j, components[idx]))
                        components[idx].remaining_quantity -= 1
                        placed_quantity += 1
                        cur[idx]+=1
                        if components[idx].type == "Rectangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1]
                        elif components[idx].type == "Circle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.pi / 4
                        elif components[idx].type == "Triangle":
                            used_area += components[idx].dimensions[0] * components[idx].dimensions[1] * math.sqrt(3) / 4
                        all_placed = False
        remaining_area = material_width * material_height - used_area
        if remaining_area <= 0 or all_placed:
            break
    return packed_items, remaining_area


def try_place_component(material_grid, row, col, component):
    height, width = len(material_grid), len(material_grid[0])
    if row + component.dimensions[0] > height or col + component.dimensions[1] > width:
        return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            if material_grid[row + i][col + j] != 0:
                return False
    for i in range(component.dimensions[0]):
        for j in range(component.dimensions[1]):
            material_grid[row + i][col + j] = component.type
    return True
def plot_packing(material_width, material_height, packed_items):
    fig, ax = plt.subplots()
    ax.set_xlim([0, material_width])
    ax.set_ylim([0, material_height])
    for item in packed_items:
        component = item[2]
        if component.type == "Rectangle":
            rect = patches.Rectangle((item[1], item[0]), component.dimensions[1], component.dimensions[0], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(rect)
        elif component.type == "Circle":
            circle = patches.Circle((item[1] + component.dimensions[1] / 2, item[0] + component.dimensions[0] / 2), component.dimensions[1] / 2, linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(circle)
        elif component.type == "Triangle":
            triangle = patches.Polygon([
                (item[1], item[0] + component.dimensions[0]),
                (item[1] + component.dimensions[1] / 2, item[0]),
                (item[1] + component.dimensions[1], item[0] + component.dimensions[0])
            ], linewidth=1, edgecolor='b', facecolor='none')
            ax.add_patch(triangle)
    plt.gca().set_aspect('equal', adjustable='box')
    plt.title(f'Packing Result for Components')
    plt.show()
components = [
  Component("Rectangle", (30, 8), 100),
  Component("Rectangle", (25, 5), 20),
  Component("Rectangle", (5, 5), 100),
  Component("Triangle", (10, 10), 200),
  Component("Triangle", (8, 8), 200),
  Component("Triangle", (16, 16), 50),
  Component("Triangle", (20, 20), 60),
  Component("Circle", (20, 20), 20),
  Component("Circle", (16, 16), 60),
  Component("Circle", (30, 30), 20),
  Component("Circle", (26, 26), 60),
]
cnt = [0 for _ in components]
remaining_area_array = []
used = 0
while sum([i.remaining_quantity for i in components]) != 0:
    cur = [0 for _ in components]
    each_time = time.time()
    used += 1
    material_width = 200
    material_height = 200
    area = material_width * material_height
    packed_items, remaining_area = pack_components(material_width, material_height, components)
    plot_packing(material_width, material_height, packed_items)
    print(f"Remaining Area%: {remaining_area / area}")
    remaining_area_array.append(float(remaining_area / area))
    print(f" each time : {time.time() - each_time}")
    cnt = [x + y for x, y in zip(cnt, cur)]
    for i, component in enumerate(components):
        print(f"{i + 1}. {component.type},{component.dimensions}, {component.quantity}, remaining: {component.remaining_quantity}, total_count: {cnt[i]}, count: {cur[i]}")
print(f' total use time {time.time()-start}')
print(f' use leather {used} pieces')
print(f' remaining_area {remaining_area_array}')
# Out:
# Remaining Area%: 0.24271399704374663
#  each time : 0.9390006065368652
# 1. Circle,(30, 30), 20, remaining: 0, total_count: 20, count: 20
# 2. Circle,(26, 26), 60, remaining: 34, total_count: 26, count: 26
# 3. Triangle,(20, 20), 60, remaining: 56, total_count: 4, count: 4
# 4. Circle,(20, 20), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(16, 16), 50, remaining: 47, total_count: 3, count: 3
# 6. Circle,(16, 16), 60, remaining: 60, total_count: 0, count: 0
# 7. Rectangle,(30, 8), 100, remaining: 98, total_count: 2, count: 2
# 8. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 9. Triangle,(10, 10), 200, remaining: 198, total_count: 2, count: 2
# 10. Triangle,(8, 8), 200, remaining: 197, total_count: 3, count: 3
# 11. Rectangle,(5, 5), 100, remaining: 73, total_count: 27, count: 27
# Remaining Area%: 0.3683285973745018
#  each time : 0.8890335559844971
# 1. Circle,(30, 30), 20, remaining: 0, total_count: 20, count: 0
# 2. Circle,(26, 26), 60, remaining: 0, total_count: 60, count: 34
# 3. Triangle,(20, 20), 60, remaining: 25, total_count: 35, count: 31
# 4. Circle,(20, 20), 20, remaining: 20, total_count: 0, count: 0
# 5. Triangle,(16, 16), 50, remaining: 38, total_count: 12, count: 9
# 6. Circle,(16, 16), 60, remaining: 60, total_count: 0, count: 0
# 7. Rectangle,(30, 8), 100, remaining: 98, total_count: 2, count: 0
# 8. Rectangle,(25, 5), 20, remaining: 20, total_count: 0, count: 0
# 9. Triangle,(10, 10), 200, remaining: 182, total_count: 18, count: 16
# 10. Triangle,(8, 8), 200, remaining: 195, total_count: 5, count: 2
# 11. Rectangle,(5, 5), 100, remaining: 69, total_count: 31, count: 4
# Remaining Area%: 0.40485772904119166
#  each time : 0.8640270233154297
# 1. Circle,(30, 30), 20, remaining: 0, total_count: 20, count: 0
# 2. Circle,(26, 26), 60, remaining: 0, total_count: 60, count: 0
# 3. Triangle,(20, 20), 60, remaining: 0, total_count: 60, count: 25
# 4. Circle,(20, 20), 20, remaining: 0, total_count: 20, count: 20
# 5. Triangle,(16, 16), 50, remaining: 0, total_count: 50, count: 38
# 6. Circle,(16, 16), 60, remaining: 20, total_count: 40, count: 40
# 7. Rectangle,(30, 8), 100, remaining: 96, total_count: 4, count: 2
# 8. Rectangle,(25, 5), 20, remaining: 19, total_count: 1, count: 1
# 9. Triangle,(10, 10), 200, remaining: 182, total_count: 18, count: 0
# 10. Triangle,(8, 8), 200, remaining: 183, total_count: 17, count: 12
# 11. Rectangle,(5, 5), 100, remaining: 69, total_count: 31, count: 0
# Remaining Area%: 0.16343579240164618
#  each time : 0.6801056861877441
# 1. Circle,(30, 30), 20, remaining: 0, total_count: 20, count: 0
# 2. Circle,(26, 26), 60, remaining: 0, total_count: 60, count: 0
# 3. Triangle,(20, 20), 60, remaining: 0, total_count: 60, count: 0
# 4. Circle,(20, 20), 20, remaining: 0, total_count: 20, count: 0
# 5. Triangle,(16, 16), 50, remaining: 0, total_count: 50, count: 0
# 6. Circle,(16, 16), 60, remaining: 0, total_count: 60, count: 20
# 7. Rectangle,(30, 8), 100, remaining: 0, total_count: 100, count: 96
# 8. Rectangle,(25, 5), 20, remaining: 0, total_count: 20, count: 19
# 9. Triangle,(10, 10), 200, remaining: 104, total_count: 96, count: 78
# 10. Triangle,(8, 8), 200, remaining: 165, total_count: 35, count: 18
# 11. Rectangle,(5, 5), 100, remaining: 63, total_count: 37, count: 6
# Remaining Area%: 0.7337263442084763
#  each time : 0.43601226806640625
# 1. Circle,(30, 30), 20, remaining: 0, total_count: 20, count: 0
# 2. Circle,(26, 26), 60, remaining: 0, total_count: 60, count: 0
# 3. Triangle,(20, 20), 60, remaining: 0, total_count: 60, count: 0
# 4. Circle,(20, 20), 20, remaining: 0, total_count: 20, count: 0
# 5. Triangle,(16, 16), 50, remaining: 0, total_count: 50, count: 0
# 6. Circle,(16, 16), 60, remaining: 0, total_count: 60, count: 0
# 7. Rectangle,(30, 8), 100, remaining: 0, total_count: 100, count: 0
# 8. Rectangle,(25, 5), 20, remaining: 0, total_count: 20, count: 0
# 9. Triangle,(10, 10), 200, remaining: 0, total_count: 200, count: 104
# 10. Triangle,(8, 8), 200, remaining: 0, total_count: 200, count: 165
# 11. Rectangle,(5, 5), 100, remaining: 0, total_count: 100, count: 63
#  total use time 3.8091862201690674
#  use leather 5 pieces
#  remaining_area [0.24271399704374663, 0.3683285973745018, 0.40485772904119166, 0.16343579240164618, 0.7337263442084763]
